# %%
import nltk
import string
import re
import csv

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

listtoken=[]
count = 0

def tokenizing(text):
    #hapus url dari kalimat dan mention
    clean_text=re.sub(r"(?:\@|http?\://|https?\://|www)\S+"," ",text)

    #hapus hashtags
    clean_text=re.sub("#[A-Za-z0-9_]+"," ",clean_text)

    #casefolding
    cf_result = clean_text.lower()

    #tokenizing
    tkn_result = re.sub(r"\d+"," ",cf_result) #hapus angka

    #pattern = re.compile(r'[^A-Za-z ]+', re.UNICODE)
    tkn_result = re.sub(r'[^a-z\s]+',' ',tkn_result) #hapus non alphanumerik karakter

    #hapus whitespace d awal dan akhir
    #tkn_result = tkn_result.translate(str.maketrans("","",string.punctuation))
    tkn_result = tkn_result.strip()

    #hapus multiple spasi karakter
    tkn_result = re.sub('\s+',' ',tkn_result)
    tokens = nltk.tokenize.word_tokenize(tkn_result)

    #hapus kata sambung/stopwords
    list_stopwords = nltk.corpus.stopwords.words('indonesian')
    stopword_tambahan = ['yg','gitu','aja','gini','ajah','kalo','ah','nihhh','hahaha','wkwkwkw','deh','or','sih']
    list_stopwords.extend(stopword_tambahan)
    tkn_no_stopwords = [word for word in tokens if not word in list_stopwords]

    #----stemmer (hapus imbuhan)
    #----create stemmer
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()

    #---- token without stopword
    list_tokens = tkn_no_stopwords
    output   = [(stemmer.stem(token)) for token in list_tokens]
    return output

#with open("datatrain/wildlife_trade.csv","r") as csv_file:
with open("datatrain/misc.csv","r") as csv_file:    
    csv_read = csv.reader(csv_file,delimiter=',')
    for line in csv_read:
        count+=1
        print("Memproses data ke-"+ str(count) +":")
        listtoken.append(tokenizing(line[0]))
        #print("selesai")
        print(tokenizing(line[0]))
#print(listtoken)
print("Sebanyak %s tweet telah diproses" % count)
# Out:
# Memproses data ke-1:
# ['pria', 'bengkulu', 'batal', 'jual', 'kulit', 'harimau', 'meter']
# Memproses data ke-2:
# ['nilai', 'jual', 'kulit', 'harimau', 'sumatra', 'buru', 'populasi', 'tinggal', 'ekor', 'bsk', 'wib']
# Memproses data ke-3:
# ['bukti', 'jual', 'kulit', 'harimau', 'laku', 'bebas']
# Memproses data ke-4:
# ['jual', 'kulit', 'harimau', 'sumatera', 'pria', 'tangkap']
# Memproses data ke-5:
# ['orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta']
# Memproses data ke-6:
# ['jual', 'kulit', 'harimau', 'kades', 'bekuk']
# Memproses data ke-7:
# ['nilai', 'jual', 'kulit', 'harimau', 'sumatera', 'percaya', 'kuat', 'mistis', 'raja', 'hutan', 'buru']
# Memproses data ke-8:
# ['jual', 'kulit', 'harimau', 'sumatera', 'keluarga', 'usaha', 'tangkap']
# Memproses data ke-9:
# ['jual', 'kulit', 'harimau', 'warga', 'riau', 'sumbar', 'tangkap', 'jambi']
# Memproses data ke-10:
# ['jual', 'kulit', 'harimau', 'rp', 'juta', 'pria', 'bireuen', 'tangkap', 'polisi', 'daerah', 'aceh', 'tangkap', 'as', 'sangka', 'pel']
# Memproses data ke-11:
# ['jual', 'kulit', 'harimau', 'dagang', 'tuntut', 'penjara']
# Memproses data ke-12:
# ['nonton', 'sedih', 'jual', 'kulit', 'harimau', 'sumatera', 'noooo']
# Memproses data ke-13:
# ['izin', 'agen', 'kulit', 'ular', 'biawak', 'jual', 'kulit', 'harimau']
# Memproses data ke-14:
# ['jual', 'kulit', 'harimau', 'kelamin', 'rusa', 'warga', 'medan', 'bekuk', 'polisi']
# Memproses data ke-15:
# ['tahan', 'jual', 'kulit', 'harimau', 'sumatera']
# Memproses data ke-16:
# ['tangkap', 'jual', 'kulit', 'harimau', 'aku', 'sangka']
# Memproses data ke-17:
# ['warga', 'inhu', 'riau', 'pergok', 'jual', 'kulit', 'harimau', 'sumatera']
# Memproses data ke-18:
# ['jual', 'kulit', 'harimau', 'sumatera', 'rp', 'juta', 'polisi', 'tangkap', 'pria', 'bener', 'riah']
# Memproses data ke-19:
# ['warga', 'jambi', 'jual', 'kulit', 'harimau', 'sumatera', 'bekuk']
# Memproses data ke-20:
# ['jual', 'kulit', 'harimau', 'rp', 'juta', 'buru', 'ancam', 'bui']
# Memproses data ke-21:
# ['jual', 'kulit', 'harimau', 'sisik', 'trenggiling', 'dakwa', 'ancam', 'penjara', 'ping', 'situs']
# Memproses data ke-22:
# ['pria', 'langkat', 'jual', 'kulit', 'harimau', 'utuh', 'harga', 'rp', 'juta']
# Memproses data ke-23:
# ['jual', 'kulit', 'harimau', 'sumatera', 'residivis', 'aceh', 'ganjar', 'penjara']
# Memproses data ke-24:
# ['jual', 'kulit', 'harimau', 'tani', 'langkat', 'tangkap', 'polisi']
# Memproses data ke-25:
# ['jual', 'kulit', 'harimau', 'harga', 'rp', 'juta', 'buru', 'tangkap', 'laku', 'buru', 'jual', 'kulit', 'hewan', 'dil']
# Memproses data ke-26:
# ['orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta', 'bbksda', 'riau', 'hasil', 'gagal', 'penj']
# Memproses data ke-27:
# ['jual', 'kulit', 'harimau', 'sumatera', 'laku', 'bekuk', 'tugas', 'nyamar']
# Memproses data ke-28:
# ['jual', 'kulit', 'harimau', 'sumatera', 'macan', 'dahan', 'pria', 'paruh', 'baya', 'tangkap', 'polisi']
# Memproses data ke-29:
# ['jual', 'kulit', 'harimau', 'sumatera', 'ismail', 'hukum', 'penjara']
# Memproses data ke-30:
# ['jual', 'kulit', 'harimau', 'sembiring', 'vonis']
# Memproses data ke-31:
# ['warga', 'inhu', 'riau', 'pergok', 'jual', 'kulit', 'harimau', 'sumatera', 'kulit', 'harimau', 'milik', 'disur']
# Memproses data ke-32:
# ['jual', 'kulit', 'harimau', 'sisik', 'trenggiling', 'dakwa', 'ancam', 'penjara']
# Memproses data ke-33:
# ['pasutri', 'jambi', 'jual', 'kulit', 'harimau', 'sumatera', 'orang', 'kaya', 'harimau', 'sumatera', 'pasutri', 'j']
# Memproses data ke-34:
# ['giur', 'untung', 'rp', 'juta', 'warga', 'inhu', 'cokok', 'jual', 'kulit', 'harimau']
# Memproses data ke-35:
# ['home', 'peristiwa', 'berita', 'tahu', 'jual', 'kulit', 'harimau', 'warga', 'sumatera', 'utara', 'new']
# Memproses data ke-36:
# ['jual', 'kulit', 'harimau', 'sumatera', 'laku', 'bekuk', 'tugas', 'nyamar']
# Memproses data ke-37:
# ['jual', 'kulit', 'harimau', 'warga', 'sumbar', 'tangkap', 'polisi']
# Memproses data ke-38:
# ['detiknews', 'warga', 'inhu', 'riau', 'pergok', 'jual', 'kulit', 'harimau', 'sumatera', 'kulit', 'harimau', 'milik', 'h']
# Memproses data ke-39:
# ['jual', 'kulit', 'harimau', 'sisik', 'trenggiling', 'dakwa', 'ancam', 'penjara']
# Memproses data ke-40:
# ['jual', 'kulit', 'harimau', 'sumatera', 'laku', 'bekuk', 'tugas', 'nyamar']
# Memproses data ke-41:
# ['orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta', 'bbksda', 'riau', 'hasil', 'gagal', 'jual', 'kulit', 'harimau', 'dewa']
# Memproses data ke-42:
# ['jual', 'kulit', 'harimau', 'harga', 'rp', 'juta', 'buru', 'tangkap', 'laku', 'buru', 'jual', 'kulit', 'hewan', 'dil']
# Memproses data ke-43:
# ['jual', 'kulit', 'harimau', 'sumatera', 'residivis', 'aceh', 'ganjar', 'penjara', 'p', 'via']
# Memproses data ke-44:
# ['izin', 'agen', 'kulit', 'ular', 'biawak', 'jual', 'kulit', 'harimau', 'nasib', 'harimau', 'khawatir', 'buru']
# Memproses data ke-45:
# ['jual', 'kulit', 'harimau', 'beruang', 'ancam', 'hukum', 'sangka']
# Memproses data ke-46:
# ['orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta', 'bbksda']
# Memproses data ke-47:
# ['izin', 'agen', 'kulit', 'ular', 'biawak', 'jual', 'kulit', 'harimau']
# Memproses data ke-48:
# ['pasutri', 'jambi', 'jual', 'kulit', 'harimau', 'sumatera', 'orang', 'kaya', 'harimau', 'sumatera', 'pasutri', 'j']
# Memproses data ke-49:
# ['warga', 'inhu', 'riau', 'pergok', 'jual', 'kulit', 'harimau', 'sumatera', 'kulit', 'harimau', 'milik', 'disur']
# Memproses data ke-50:
# ['izin', 'agen', 'kulit', 'ular', 'biawak', 'jual', 'kulit', 'harimau']
# Memproses data ke-51:
# ['jual', 'kulit', 'harimau', 'beruang', 'ancam', 'hukum', 'sangka']
# Memproses data ke-52:
# ['detiknews', 'warga', 'inhu', 'riau', 'pergok', 'jual', 'kulit', 'harimau', 'sumatera', 'kulit', 'harimau', 'milik', 'h']
# Memproses data ke-53:
# ['orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta', 'bbksda', 'riau', 'hasil', 'gagal', 'jual', 'kulit', 'harimau', 'dewa']
# Memproses data ke-54:
# ['pasutri', 'jambi', 'jual', 'kulit', 'harimau', 'sumatera', 'orang', 'kaya', 'harimau', 'sumatera', 'pasutri', 'j']
# Memproses data ke-55:
# ['jual', 'kulit', 'harimau', 'harga', 'rp', 'juta', 'buru', 'tangkap', 'laku', 'buru', 'jual', 'kulit', 'hewan', 'dil']
# Memproses data ke-56:
# ['jual', 'kulit', 'harimau', 'sumatra', 'hakim', 'vonis', 'dakwa', 'penjara', 'sepakat', 'hasil', 'jual', 'kulit', 'harimau', 'maxsi', 'oleh', 'rp', 'juta']
# Memproses data ke-57:
# ['jual', 'kulit', 'harimau', 'tani', 'langkat', 'ringkus']
# Memproses data ke-58:
# ['orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta', 'bbksda', 'riau', 'hasil', 'gagal', 'penj']
# Memproses data ke-59:
# ['warga', 'inhu', 'riau', 'pergok', 'jual', 'kulit', 'harimau', 'sumatera']
# Memproses data ke-60:
# ['izin', 'agen', 'kulit', 'ular', 'biawak', 'jual', 'kulit', 'harimau', 'nasib', 'harimau', 'khawatir', 'buru']
# Memproses data ke-61:
# ['jual', 'kulit', 'harimau', 'sumatera', 'residivis', 'aceh', 'ganjar', 'penjara', 'adil', 'negeri', 'bireuen', 'memv']
# Memproses data ke-62:
# ['jual', 'kulit', 'harimau', 'harga', 'rp', 'juta', 'buru', 'tangkap', 'laku', 'buru', 'jual', 'kulit', 'hewan', 'dil']
# Memproses data ke-63:
# ['warga', 'inhu', 'riau', 'pergok', 'jual', 'kulit', 'harimau', 'sumatera']
# Memproses data ke-64:
# ['jual', 'kulit', 'harimau', 'harga', 'rp', 'juta', 'buru', 'tangkap', 'laku', 'buru', 'jual', 'kulit', 'hewan', 'dil']
# Memproses data ke-65:
# ['tahan', 'cuba', 'jual', 'kulit', 'harimau', 'sumatera']
# Memproses data ke-66:
# ['jual', 'kulit', 'harimau', 'waris', 'kakek', 'tani', 'sumut', 'aman', 'tugas', 'gakkum', 'lhk']
# Memproses data ke-67:
# ['orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta', 'bbksda', 'riau', 'hasil', 'gagal', 'penj']
# Memproses data ke-68:
# ['jual', 'kulit', 'harimau', 'harga', 'rp', 'juta', 'buru', 'tangkap']
# Memproses data ke-69:
# ['detiknews', 'orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta', 'bbksda', 'riau', 'hasil', 'menggag']
# Memproses data ke-70:
# ['jual', 'kulit', 'harimau', 'harga', 'rp', 'juta', 'buru', 'tangkap']
# Memproses data ke-71:
# ['orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta', 'bbksda', 'riau', 'hasil', 'gagal', 'penj']
# Memproses data ke-72:
# ['detik', 'warga', 'inhu', 'riau', 'pergok', 'jual', 'kulit', 'harimau', 'sumatera']
# Memproses data ke-73:
# ['warga', 'inhu', 'bekuk', 'jual', 'kulit', 'harimau', 'tugas']
# Memproses data ke-74:
# ['jual', 'kulit', 'harimau', 'sumatera', 'ismail', 'hukum', 'penjara']
# Memproses data ke-75:
# ['jual', 'kulit', 'harimau', 'sumatera', 'laku', 'bekuk', 'tugas', 'nyamar']
# Memproses data ke-76:
# ['jual', 'kulit', 'harimau', 'ismail', 'tuntut', 'bui']
# Memproses data ke-77:
# ['detik', 'orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta']
# Memproses data ke-78:
# ['detik', 'orang', 'tangkap', 'bbksda', 'riau', 'jual', 'kulit', 'harimau', 'rp', 'juta', 'bbksda', 'riau', 'hasil']
# Memproses data ke-79:
# ['orang', 'coba', 'jual', 'bayi', 'harimau', 'sumatera', 'facebook', 'timlonet']
# Memproses data ke-80:
# ['mimpi', 'clara', 'jual', 'baju', 'second', 'hand', 'digantungin', 'bawah', 'ternak', 'ayam', 'bayi', 'harimau', 'orang', 'ngethrift', 'bingung']
# Memproses data ke-81:
# ['cina', 'd', 'jual', 'tulang', 'harimau', 'kapsul', 'serbuk', 'daging', 'manusia', 'minum', 'plasenta', 'bayi', 'l']
# Memproses data ke-82:
# ['punten', 'tau', 'ga', 'jual', 'baju', 'bayi', 'karakter', 'lebah', 'harimau', 'kelinci', 'dsb', 'nuhun']
# Memproses data ke-83:
# ['ahok', 'tolong', 'benah', 'ragunan', 'pawang', 'jual', 'anak', 'satwa', 'area', 'harimau', 'kl', 'bayi', 'lahir', 'gak', 'lapor']
# Memproses data ke-84:
# ['kulit', 'jok', 'gambar', 'harimau', 'bayar', 'cod', 'silah', 'dm', 'wa', 'kendy', 'jok', 'motor']
# Memproses data ke-85:
# ['dagang', 'kulit', 'harimau', 'ilegal', 'tangkap', 'tim', 'bksda', 'dinas', 'hutan', 'jambi', 'tangkap', 'pria', 'me']
# Memproses data ke-86:
# ['harimau', 'sumatera', 'tinggal', 'tulang', 'kulit', 'harimau', 'sumatera', 'nyata', 'satwa', 'langka', 'd']
# Memproses data ke-87:
# ['polisi', 'gagal', 'jual', 'kulit', 'harimau', 'rejang', 'lebong', 'tvone', 'polisi', 'resor', 'rejang', 'lebong', 'bengkulu', 'meng']
# Memproses data ke-88:
# ['pasar', 'permai', 'koja', 'jual', 'kulit', 'kuku', 'gigi', 'harimau', 'tolong', 'tindak']
# Memproses data ke-89:
# ['gigi', 'gigi', 'drakula', 'd', 'jual', 'emang', 'harimau', 'oyak', 'daging', 'mangsa', 'gigi']
# Memproses data ke-90:
# ['gue', 'curiga', 'gigi', 'palsu', 'pakai', 'ggs', 'ama', 'pacar', 'harimau', 'gigi', 'palus', 'jual', 'abang', 'sd']
# Memproses data ke-91:
# ['abis', 'jual', 'c', 'kebun', 'binatang', 'tusuk', 'gigi', 'harimau', 'ntar', 'jual', 'c', 'mamang', 'taraje', 'spare', 'part', 'nanana']
# Memproses data ke-92:
# ['abg', 'ngawankan', 'harimau', 'jual', 'koran', 'sambel', 'nyikat', 'giginye', 'abang', 'tukang', 'koran', 'tukang', 'sikat', 'gigi', 'harimau', 'sbenarny']
# Memproses data ke-93:
# ['haha', 'gigi', 'anak', 'harimau', 'jual']
# Memproses data ke-94:
# ['woii', 'esok', 'dah', 'stat', 'jual', 'dah', 'tiket', 'kemonnn', 'harimau', 'payah', 'sarap', 'gosok', 'gigi', 'jgn', 'stadium', 'haha']
# Memproses data ke-95:
# ['haah', 'gigi', 'tiger', 'cute', 'kikik', 'orang', 'tu', 'gigi', 'patah', 'nak', 'ganti', 'gigi', 'harimau', 'jual', 'mahal', 'haha']
# Memproses data ke-96:
# ['sangka', 'polisi', 'sita', 'kulit', 'tengkorak', 'gigi', 'tulang', 'harimau', 'masuk', 'tas', 'jual']
# Memproses data ke-97:
# ['jual', 'kumis', 'harimau', 'hukum', 'kompas', 'com', 'sains', 'unt']
# Memproses data ke-98:
# ['jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-99:
# ['new', 'post', 'jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-100:
# ['majalah', 'online', 'com', 'jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-101:
# ['jual', 'kumis', 'harimau', 'hukum', 'situsportal', 'com', 'kurang', 'lahan', 'indonesia', 'habitat']
# Memproses data ke-102:
# ['kompas', 'jual', 'kumis', 'harimau', 'hukum', 'lmao']
# Memproses data ke-103:
# ['jual', 'kumis', 'harimau', 'skrg', 'kena', 'hukum', 'thn', 'lho', 'pdhl', 'dipake', 'campur', 'jamu']
# Memproses data ke-104:
# ['jual', 'kumis', 'harimau', 'hukum', 'lindung', 'satwa', 'langka', 'harimau', 'sumatera', 'perintah', 'sus']
# Memproses data ke-105:
# ['jual', 'kumis', 'harimau', 'hukum', 'lindung', 'satwa', 'langka', 'harimau', 'sumatera', 'perintah', 'sus']
# Memproses data ke-106:
# ['majalah', 'online', 'com', 'jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-107:
# ['majalah', 'online', 'com', 'jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-108:
# ['jual', 'kumis', 'harimau', 'hukum', 'via']
# Memproses data ke-109:
# ['jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-110:
# ['jual', 'kumis', 'harimau', 'hukum', 'lindung', 'satwa', 'langka', 'harimau', 'sumatera', 'perintah', 'sus']
# Memproses data ke-111:
# ['jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-112:
# ['jual', 'kumis', 'harimau', 'hukum', 'via']
# Memproses data ke-113:
# ['jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-114:
# ['dduk', 'mkn', 'dtg', 'org', 'jual', 'bulu', 'gajah', 'dgn', 'kuku', 'harimau', 'pelik', 'je']
# Memproses data ke-115:
# ['ndak', 'paham', 'laaa', 'orang', 'jual', 'pc', 'condi', 'nya', 'udah', 'teken', 'kuku', 'harimau']
# Memproses data ke-116:
# ['pasar', 'permai', 'koja', 'jual', 'kulit', 'kuku', 'gigi', 'harimau', 'tolong', 'tindak']
# Memproses data ke-117:
# ['emg', 'trend', 'ya', 'kuku', 'pukat', 'harimau']
# Memproses data ke-118:
# ['jual', 'kuku', 'harimau', 'sumatera', 'asli', 'buyer', 'alas', 'wibawa', 'nilai', 'magis']
# Memproses data ke-119:
# ['jual', 'kuku', 'kulit', 'harimau', 'suwarno', 'tangkap', 'polisi']
# Memproses data ke-120:
# ['perhilitan', 'tahan', 'warga', 'india', 'jual', 'kuku', 'harimau', 'via']
# Memproses data ke-121:
# ['jual', 'kuku', 'kulit', 'harimau', 'suwarno', 'tangkap', 'polisi']
# Memproses data ke-122:
# ['jual', 'kuku', 'kulit', 'harimau', 'suwarno', 'tangkap', 'polisi']
# Memproses data ke-123:
# ['jual', 'kuku', 'kulit', 'harimau', 'suwarno', 'tangkap', 'polisi']
# Memproses data ke-124:
# ['jual', 'kumis', 'harimau', 'hukum', 'kompas', 'com', 'sains', 'unt']
# Memproses data ke-125:
# ['jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-126:
# ['new', 'post', 'jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-127:
# ['majalah', 'online', 'com', 'jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-128:
# ['jual', 'kumis', 'harimau', 'hukum', 'situsportal', 'com', 'kurang', 'lahan', 'indonesia', 'habitat']
# Memproses data ke-129:
# ['kompas', 'jual', 'kumis', 'harimau', 'hukum', 'lmao']
# Memproses data ke-130:
# ['jual', 'kumis', 'harimau', 'skrg', 'kena', 'hukum', 'thn', 'lho', 'pdhl', 'dipake', 'campur', 'jamu']
# Memproses data ke-131:
# ['jual', 'kumis', 'harimau', 'hukum', 'lindung', 'satwa', 'langka', 'harimau', 'sumatera', 'perintah', 'sus']
# Memproses data ke-132:
# ['jual', 'kumis', 'harimau', 'hukum', 'lindung', 'satwa', 'langka', 'harimau', 'sumatera', 'perintah', 'sus']
# Memproses data ke-133:
# ['majalah', 'online', 'com', 'jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-134:
# ['majalah', 'online', 'com', 'jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-135:
# ['jual', 'kumis', 'harimau', 'hukum', 'kumis', 'gua', 'umur', 'hidup', 'hammer']
# Memproses data ke-136:
# ['jual', 'kumis', 'harimau', 'hukum', 'via']
# Memproses data ke-137:
# ['jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-138:
# ['jual', 'kumis', 'harimau', 'hukum', 'lindung', 'satwa', 'langka', 'harimau', 'sumatera', 'perintah', 'sus']
# Memproses data ke-139:
# ['jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-140:
# ['jual', 'kumis', 'harimau', 'hukum', 'via']
# Memproses data ke-141:
# ['jual', 'kumis', 'harimau', 'hukum']
# Memproses data ke-142:
# ['harimau', 'putih', 'jinak', 'anak', 'harimau', 'putih', 'anak', 'singa', 'putih']
# Memproses data ke-143:
# ['nak', 'plok', 'main', 'main', 'dgn', 'anak', 'harimau', 'comel', 'nak', 'jinak', 'je', 'laaaa']
# Memproses data ke-144:
# ['foto', 'anak', 'harimau', 'klu', 'ga', 'kasi', 'obat', 'tidur', 'biar', 'jinak', 'ga', 'ky', 't']
# Memproses data ke-145:
# ['semalem', 'mimpi', 'dapet', 'anak', 'harimau', 'super', 'jinak']
# Memproses data ke-146:
# ['comel', 'anak', 'harimau', 'ni', 'jinak', 'haihhh', 'gomol']
# Memproses data ke-147:
# ['melihara', 'anak', 'harimau', 'jinak', 'uda', 'gedek', 'kita', 'makan']
# Memproses data ke-148:
# ['anak', 'harimau', 'jawa', 'lucu', 'jg', 'anak', 'kucing', 'jinak']
# Memproses data ke-149:
# ['nntn', 'trans', 'lucu', 'anak', 'harimau', 'kaya', 'jinak', 'kaya', 'kucing', 'drmh', 'gw']
# Memproses data ke-150:
# ['anak', 'harimau', 'putih', 'jinak', 'baby', 'baby', 'zoo', 'ingin', 'nak', 'tengok', 'and', 'pegang', 'tu', 'my', 'fav', 'animals', 'hm', 'siapa']
# Memproses data ke-151:
# ['orang', 'nanyanya', 'ttg', 'gajah', 'harimau', 'anak', 'gajah', 'pawang', 'gajah', 'way', 'kambas', 'gajah', 'jinak', 'gajah', 'liar']
# Memproses data ke-152:
# ['comelnyaaaa', 'anak', 'harimau', 'tuuu', 'jinak', 'eee', 'geram', 'xd']
# Memproses data ke-153:
# ['harimau', 'jinak', 'anak']
# Memproses data ke-154:
# ['cute', 'la', 'anak', 'harimau', 'ni', 'la', 'jinak', 'mcm', 'kucing', 'and', 'makan', 'org', 'dah', 'bela', 'jd', 'binatang', 'pelihara', 'ni']
# Memproses data ke-155:
# ['haha', 'kirain', 'jinak', 'hati', 'teteh', 'd', 'jinak', 'anak', 'harimau', 'jinak', 'mna', 'anak', 'ayam', 'teh']
# Memproses data ke-156:
# ['mcm', 'anak', 'harimau', 'jew', 'sbb', 'jinak', 'mcm', 'and', 'ngan', 'pakcik', 'bjh', 'putih', 'tu', 'mcm', 'nak', 'main', 'seronok', 'lari', 'anak', 'ayam']
# Memproses data ke-157:
# ['kak', 'eton', 'ni', 'time', 'kerja', 'harimau', 'hilang', 'anak', 'bile', 'jumpe', 'laki', 'kucing', 'jinak']
# Memproses data ke-158:
# ['drpd', 'lipas', 'kena', 'kenal', 'kpd', 'anak', 'buah', 'haiwan', 'jinak', 'kucing', 'kambing', 'biawak', 'zirafah', 'harimau', 'bintang']
# Memproses data ke-159:
# ['selfie', 'anak', 'harimau', 'hihihi', 'udh', 'jinak']
# Memproses data ke-160:
# ['haha', 'anak', 'harimau', 'mmg', 'laaa', 'jinak', 'hehe']
# Memproses data ke-161:
# ['abang', 'nak', 'harimau', 'jadila', 'harimau', 'sarkas', 'comel', 'jinak', 'peluk', 'yohhh', 'kenjet', 'anak', 'yaa', 'nyurah', 'tido', 'indah']
# Memproses data ke-162:
# ['tgk', 'vid', 'org', 'kg', 'saksi', 'rimau', 'tue', 'igt', 'sarkas', 'taknak', 'kalah', 'tgh', 'dukung', 'anak', 'tue', 'jinak', 'jinak', 'tue', 'harimau', 'haiwan', 'karnivor', 'tau', 'dop', 'karnivor', 'dop', 'ahu', 'baca', 'molek']
# Memproses data ke-163:
# ['azhar', 'bdak', 'pling', 'bodo', 'kt', 'dunia', 'nie', 'ad', 'kw', 'kucing', 'kte', 'anak', 'harimau', 'jinak', 'dasar', 'otak', 't', 'blik']
# Memproses data ke-164:
# ['amazed', 'eh', 'harimau', 'nya', 'jinak', 'sweet', 'anak', 'anak', 'nya', 'cuteeeeee']
# Memproses data ke-165:
# ['sy', 'pegang', 'anak', 'harimau', 'tu', 'zoo', 'series', 'seronok', 'jinak', 'cute']
# Memproses data ke-166:
# ['pgn', 'melihara', 'anak', 'harimau', 'biar', 'jinak', 'udah', 'gede', 'bsa', 'main', 'bareng', 'biar', 'anti', 'mainstream']
# Memproses data ke-167:
# ['sufi', 'minat', 'haiwan', 'bela', 'anak', 'harimau', 'akar', 'smpai', 'jinak', 'dgn', 'sufi', 'tk', 'nak', 'dgn', 'org', 'tinggal', 'umur', 'tk', 'caya', 'sufi', 'jinak', 'ekor', 'musang', 'pandan', 'dr', 'usia', 'baby', 'smpai', 'umur', 'tahun', 'pas', 'tu', 'abg', 'sufi', 'serah', 'kpd', 'org', 'asli', 'rompin']
# Memproses data ke-168:
# ['coba', 'megang', 'ular', 'tp', 'ken', 'coba', 'luk', 'hewan', 'buas', 'gtu', 'buaya', 'to', 'gak', 'anak', 'harimau', 'tp', 'jinak', 'dunk']
# Memproses data ke-169:
# ['harimau', 'jinak', 'suka', 'anak', 'anak', 'harimau', 'hilang', 'jati']
# Memproses data ke-170:
# ['lucu', 'bgtttttt', 'ken', 'kaya', 'anak', 'harimau', 'jinak', 'flish']
# Memproses data ke-171:
# ['harimau', 'jinak', 'makan', 'sagu', 'kandang', 'nih', 'anak', 'belagu', 'tendang']
# Memproses data ke-172:
# ['senang', 'hina', 'hati', 'hati', 'anak', 'harimau', 'jinak', 'dewasa', 'mangsa']
# Memproses data ke-173:
# ['jatuh', 'cinta', 'harimau', 'angkuh', 'anak', 'ayam', 'jinak', 'turut']
# Memproses data ke-174:
# ['layak', 'pelihara', 'anak', 'harimau', 'jinak', 'kecil', 'kau', 'makan']
# Memproses data ke-175:
# ['nama', 'ajar', 'sabar', 'susah', 'rawat', 'anak', 'harimau', 'biar', 'jinak', 'majikan']
# Memproses data ke-176:
# ['harimau', 'hahhahahahahahaha', 'dngn', 'jinak', 'mcm', 'anak', 'rimau']
# Memproses data ke-177:
# ['my', 'boyfriend', 'said', 'dah', 'kahwin', 'nak', 'bela', 'baby', 'harimau', 'rumah', 'then', 'bela', 'ajar', 'die', 'jinak', 'orang', 'gigit', 'orang', 'gigit', 'anak', 'patung', 'busuk', 'die', 'je', 'otak', 'dah', 'fikir', 'anak', 'harimau', 'tu', 'makan', 'anak', 'emmm']
# Memproses data ke-178:
# ['yah', 'c', 'gue', 'galak', 'kek', 'anak', 'anjing', 'nuna', 'jinak', 'kek', 'anak', 'harimau', 'sm', 'yeoja', 'muda']
# Memproses data ke-179:
# ['anak', 'kucing', 'jinak', 'xmcm', 'harimau', 'kluorg', 'xnak', 'pon', 'xmau', 'bhahaaahah']
# Memproses data ke-180:
# ['sakit', 'hati', 'mudah', 'utk', 'maaf', 'dgn', 'org', 'cinta', 'sadar', 'anak', 'harimau', 'tdk', 'slamanya', 'jinak', 'krn', 'jg', 'dewasa', 'terkam', 'mangsa']
# Memproses data ke-181:
# ['oh', 'iya', 'situ', 'harimau', 'gak', 'galak', 'anak', 'jinak', 'kyk', 'anak', 'kucing']
# Memproses data ke-182:
# ['harimau', 'ku', 'jinak', 'lg', 'kucing', 'makan', 'fiskis', 'tu', 'makan', 'owww', 'sedap', 'anak', 'bole']
# Memproses data ke-183:
# ['jinak', 'singa', 'takut', 'serius', 'anak', 'harimau', 'comel', 'gila']
# Memproses data ke-184:
# ['harimau', 'jinak', 'liat', 'rumput', 'liat', 'anak', 'rusa', 'berani', 'jamin']
# Memproses data ke-185:
# ['mimpi', 'rawat', 'anak', 'harimau', 'jinak', 'mbah', 'terimakasih']
# Memproses data ke-186:
# ['saksi', 'sang', 'harimau', 'jinak', 'tengah', 'maalam', 'jawapannya', 'tanya', 'anak', 'sy', 'mahdi', 'musa', 'orang', 'dgnnya', 'nurulhuda']
# Memproses data ke-187:
# ['terkadang', 'harimau', 'buas', 'liar', 'jinak', 'ekor', 'anak', 'kucing', 'manis']
# Memproses data ke-188:
# ['cewek', 'lg', 'bete', 'kaya', 'harimau', 'lapar', 'tp', 'udah', 'manja', 'jinak', 'kaya', 'anak', 'kucing', 'hadeh']
# Memproses data ke-189:
# ['same', 'spt', 'kau', 'de', 'yek', 'kau', 'ye', 'anak', 'harimau', 'jinak', 'induk', 'kau', 'lawan']
# Memproses data ke-190:
# ['hang', 'pi', 'youtube', 'tgk', 'anak', 'sultan', 'salman', 'bela', 'harimau', 'singa', 'rilek', 'je', 'jinak', 'nihh', 'tk', 'nk', 'ckp']
# Memproses data ke-191:
# ['uda', 'gadis', 'malam', 'pantau', 'ya', 'pra', 'gak', 'lg', 'anak', 'kola', 'harimau', 'jinak', 'pra', 'manusia']
# Memproses data ke-192:
# ['redaksiana', 'trans', 'anak', 'harimau', 'jinak', 'temu', 'santai', 'jalan', 'februari', 'via']
# Memproses data ke-193:
# ['i', 'added', 'a', 'video', 'to', 'a', 'playlist', 'redaksiana', 'trans', 'anak', 'harimau', 'jinak', 'temu', 'santai']
# Memproses data ke-194:
# ['kasi', 'yo', 'si', 'gigit', 'dikit', 'pinggang', 'ama', 'anak', 'harimau', 'putih', 'p', 'gue', 'jinak', 'tuh', 'anak', 'harimau', 'haha']
# Memproses data ke-195:
# ['hahahahaha', 'gapapa', 'anak', 'harimau', 'jinak', 'jinak', 'lucu']
# Memproses data ke-196:
# ['harimau', 'dalem', 'kandang', 'gak', 'kasi', 'makan', 'asli', 'jinak', 'ad', 'anak', 'ayam', 'numpang', 'buang', 'tai', 'langsung', 'makan', 'si', 'harimau']
# Memproses data ke-197:
# ['harimau', 'dpt', 'ku', 'jinak', 'kau', 'ku', 'anggap', 'anak', 'kahkahkah']
# Memproses data ke-198:
# ['tenang', 'kak', 'harimau', 'g', 'anak', 'ngamuk', 'klw', 'ngamung', 'kasih', 'susu', 'mas', 'psti', 'lngsng', 'jinak', 'lg']
# Memproses data ke-199:
# ['la', 'jinak', 'gek', 'ketemu', 'anak', 'harimau']
# Memproses data ke-200:
# ['ohh', 'hehe', 'awak', 'abg', 'la', 'anak', 'brapa']
# Memproses data ke-201:
# ['jg', 'tdk', 'bs', 'harap', 'harimau', 'jinak', 'klo', 'lapar', 'harap', 'anak', 'kucing', 'harimau', 'dewasa']
# Memproses data ke-202:
# ['singa', 'jinak', 'harimau', 'ya', 'buas', 'gendong', 'anak', 'singa', 'baby', 'zoo', 'taman', 'safari', 'gendong', 'bayi', 'harimau', 'gw', 'gentar', 'gendong', 'anak', 'harimau', 'anak', 'singa', 'muka', 'lucu', 'jadi', 'udah']
# Memproses data ke-203:
# ['anak', 'kucing', 'ubah', 'kucing', 'kucing', 'gak', 'ubah', 'harimau', 'kucing', 'liar', 'harimau', 'jinak', 'gak', 'percaya']
# Memproses data ke-204:
# ['jinak', 'jinak', 'anak', 'harimau']
# Memproses data ke-205:
# ['nak', 'pegi', 'zoo', 'tgk', 'anak', 'harimau', 'jinak', 'mcm', 'dlm', 'gamba', 'tu', 'dusta']
# Memproses data ke-206:
# ['keno', 'kartu', 'kuning', 'sepri', 'dpp', 'jinak', 'd', 'lantak', 'kau', 'sep', 'anak', 'harimau', 'tiduk', 'kau', 'bangunin']
# Memproses data ke-207:
# ['jinak', 'harimau', 'bukit', 'besi', 'ni', 'la', 'bela', 'kor', 'yek', 'ahmad', 'syazwan', 'moh', 'la', 'pegi', 'bukit', 'besi', 'crik', 'anak', 'bela', 'kawan', 'ngan', 'ocky']
# Memproses data ke-208:
# ['tengok', 'dokumentari', 'negara', 'kucing', 'liar', 'ni', 'kacuk', 'spesis', 'kucing', 'anak', 'kacuk', 'tu', 'bela', 'jinak', 'bela', 'kucing', 'liar', 'umpama', 'bela', 'singa', 'harimau', 'silap', 'tuan']
# Memproses data ke-209:
# ['harimau', 'inggris', 'pake', 'perfume', 'calvin', 'klein', 'biar', 'jinak', 'gw', 'cuman', 'pake', 'bodymist', 'nihh', 'ude', 'kelepek', 'lo', 'nihh', 'anak', 'traxx']
# Memproses data ke-210:
# ['wkk', 'gaboleh', 'promot', 'tar', 'harimau', 'mrh', 'promtin', 'ta', 'kasi', 'anak', 'org', 'wkwk', 'wkwk', 'woles', 'udah', 'jinak', 'd', 'cc']
# Memproses data ke-211:
# ['jual', 'gading', 'gajah', 'sumatera', 'pria', 'aman', 'jambi']
# Memproses data ke-212:
# ['video', 'kastam', 'china', 'serbu', 'masuk', 'rumah', 'orang', 'kaya', 'aktiviti', 'jual', 'beli', 'seludup', 'haiwan', 'liar', 'rampas', 'gading', 'gajah', 'kg', 'tanduk', 'badak', 'kg']
# Memproses data ke-213:
# ['tim', 'gabung', 'ringkus', 'laku', 'jual', 'beli', 'gading', 'gajah', 'ilegal']
# Memproses data ke-214:
# ['petisi', 'tolak', 'jual', 'beli', 'gading', 'gajah', 'online']
# Memproses data ke-215:
# ['jual', 'gading', 'gajah', 'oknum', 'dosen', 'aman', 'tugas']
# Memproses data ke-216:
# ['jual', 'gading', 'gajah', 'rp', 'miliar', 'laku', 'hukum']
# Memproses data ke-217:
# ['video', 'dakwa', 'libat', 'dana', 'hasil', 'aktiviti', 'seludup', 'jual', 'beli', 'gading', 'gajah', 'lepas']
# Memproses data ke-218:
# ['bupati', 'bener', 'riah', 'ahmadi', 'jual', 'gading', 'gajah']
# Memproses data ke-219:
# ['jual', 'gading', 'gajah', 'toko', 'online', 'indonesia', 'protes']
# Memproses data ke-220:
# ['jual', 'gading', 'gajah', 'pria', 'pati', 'bekuk', 'polisi']
# Memproses data ke-221:
# ['md', 'nawi', 'aku', 'salah', 'libat', 'aktiviti', 'seludup', 'jual', 'beli', 'gading', 'gajah', 'haram']
# Memproses data ke-222:
# ['oknum', 'pns', 'lampung', 'timur', 'tangkap', 'jual', 'gading', 'gajah', 'tribun', 'lampung', 'tribun', 'lampungoknum', 'pns']
# Memproses data ke-223:
# ['colong', 'jual', 'gading', 'gajah', 'bukalapak', 'protes', 'petisi', 'online']
# Memproses data ke-224:
# ['sedih', 'bodo', 'tembak', 'gajah', 'pastu', 'jual', 'gading', 'kesi', 'gajah', 'tu']
# Memproses data ke-225:
# ['takda', 'jual', 'gading', 'gajah', 'pasar', 'pagi', 'jaya', 'gading', 'antan', 'in', 'antan', 'pahang']
# Memproses data ke-226:
# ['jual', 'gading', 'online', 'bantu', 'jual', 'gading', 'gajah', 'toko', 'online', 'banjir', 'kecam']
# Memproses data ke-227:
# ['orang', 'dapat', 'jual', 'gading', 'gajah', 'online']
# Memproses data ke-228:
# ['jual', 'gading', 'gajah', 'yahoo', 'jepang', 'kecam']
# Memproses data ke-229:
# ['oknum', 'dosen', 'jual', 'gading', 'gajah', 'ratus', 'juta']
# Memproses data ke-230:
# ['china', 'wujud', 'janji', 'dunia', 'larang', 'jual', 'gading', 'gajah']
# Memproses data ke-231:
# ['me', 'after', 'see', 'this', 'tweet', 'gunaaaa', 'kuojiaqqqq', 'laaa', 'jual', 'gading', 'gajah', 'kot', 'babilaaa', 'babilaaa']
# Memproses data ke-232:
# ['jual', 'gading', 'gajah', 'tuntut', 'jakarta', 'selular', 'id', 'lazada']
# Memproses data ke-233:
# ['jual', 'gading', 'gajah', 'yahoo', 'jepang', 'kecam', 'situs', 'yahoo', 'jepang']
# Memproses data ke-234:
# ['jual', 'gading', 'gajah', 'rp', 'juta', 'dosen', 'stain', 'metro', 'tangkap', 'polisi']
# Memproses data ke-235:
# ['pasar', 'akik', 'jatinegara', 'jual', 'gading', 'gajah']
# Memproses data ke-236:
# ['bukalapak', 'tokopedia', 'lazada', 'kecam', 'jual', 'gading', 'gajah']
# Memproses data ke-237:
# ['polda', 'tangkap', 'pns', 'jual', 'gading', 'gajah', 'berita', 'online', 'lampung']
# Memproses data ke-238:
# ['ditreskrimsus', 'polda', 'lampung', 'ekspos', 'jual', 'gading', 'gajah']
# Memproses data ke-239:
# ['polda', 'tangkap', 'pns', 'jual', 'gading', 'gajah']
# Memproses data ke-240:
# ['update', 'today', 'oknum', 'pns', 'lampung', 'timur', 'tangkap', 'jual', 'gading', 'gajah']
# Memproses data ke-241:
# ['jual', 'gading', 'gajah', 'lazada', 'bukalapak', 'tokopedia', 'tuntut']
# Memproses data ke-242:
# ['detikcom', 'jual', 'gading', 'gajah', 'sumatera', 'pria', 'aman', 'jambi']
# Memproses data ke-243:
# ['ditreskrimsus', 'polda', 'lampung', 'ekspos', 'jual', 'gading', 'gajah']
# Memproses data ke-244:
# ['orang', 'dapat', 'jual', 'gading', 'gajah', 'online']
# Memproses data ke-245:
# ['jual', 'gading', 'gajah', 'yahoo', 'jepang', 'kecam']
# Memproses data ke-246:
# ['jual', 'gading', 'gajah', 'toko', 'online', 'kecam', 'netizen']
# Memproses data ke-247:
# ['oalah', 'menang', 'awards', 'colong', 'jual', 'gading', 'gajah']
# Memproses data ke-248:
# ['jual', 'gading', 'gajah', 'rp', 'miliar', 'laku', 'hukum']
# Memproses data ke-249:
# ['jual', 'gading', 'gajah', 'toko', 'online', 'protes']
# Memproses data ke-250:
# ['toko', 'online', 'jual', 'gading', 'gajah', 'wwf', 'desak', 'polri', 'henti', 'jual', 'gading', 'gajah']
# Memproses data ke-251:
# ['jual', 'gading', 'gajah', 'yahoo', 'jepang', 'kecam']
# Memproses data ke-252:
# ['oknum', 'pns', 'lampung', 'timur', 'tangkap', 'jual', 'gading', 'gajah']
# Memproses data ke-253:
# ['colong', 'jual', 'gading', 'gajah', 'bukalapak', 'protes', 'petisi', 'online']
# Memproses data ke-254:
# ['infochannel', 'bukalapak', 'tokopedia', 'lazada', 'kecam', 'jual', 'gading', 'gajah']
# Memproses data ke-255:
# ['jual', 'gading', 'gajah', 'yahoo', 'jepang', 'kecam', 'bas', 'ton', 'gading', 'gajah', 'laris', 'manis', 'yahoo']
# Memproses data ke-256:
# ['jual', 'gading', 'gajah', 'rp', 'miliar', 'laku', 'hukum']
# Memproses data ke-257:
# ['transaksi', 'jual', 'beli', 'gading', 'gajah', 'bongkar', 'milik', 'jaring', 'dagang', 'buru']
# Memproses data ke-258:
# ['yahoo', 'jepang', 'kecam', 'jual', 'gading', 'gajah']
# Memproses data ke-259:
# ['jual', 'gading', 'gajah', 'lazada', 'bukalapak', 'tokopedia', 'tuntut']
# Memproses data ke-260:
# ['jual', 'gading', 'gajah', 'toko', 'online', 'indonesia', 'protes']
# Memproses data ke-261:
# ['oknum', 'pns', 'lampung', 'timur', 'tangkap', 'jual', 'gading', 'gajah', 'tribun', 'lampung', 'tribun', 'lampungoknum', 'pns']
# Memproses data ke-262:
# ['jual', 'gading', 'gajah', 'pria', 'sumsel', 'aman', 'parkir', 'bank', 'mandiri', 'jambi']
# Memproses data ke-263:
# ['ditreskrimsus', 'polda', 'lampung', 'ekspos', 'jual', 'gading', 'gajah']
# Memproses data ke-264:
# ['colong', 'jual', 'gading', 'gajah', 'bukalapak', 'protes', 'petisi', 'online']
# Memproses data ke-265:
# ['jual', 'gading', 'gajah', 'rp', 'miliar', 'laku', 'hukum']
# Memproses data ke-266:
# ['netizen', 'protes', 'toko', 'online', 'jual', 'gading', 'gajah']
# Memproses data ke-267:
# ['diorg', 'jual', 'gading', 'gajah', 'kat', 'situ', 'rezza', 'bahaya']
# Memproses data ke-268:
# ['colong', 'jual', 'gading', 'gajah', 'bukalapak', 'protes', 'petisi', 'online']
# Memproses data ke-269:
# ['jual', 'gading', 'gajah', 'toko', 'online', 'indonesia', 'protes']
# Memproses data ke-270:
# ['oknum', 'pns', 'lampung', 'timur', 'tangkap', 'jual', 'gading', 'gajah', 'tribun', 'lampung', 'tribun', 'lampungoknum', 'pns']
# Memproses data ke-271:
# ['ditreskrimsus', 'polda', 'lampung', 'ekspos', 'jual', 'gading', 'gajah']
# Memproses data ke-272:
# ['jual', 'gading', 'gajah', 'rp', 'miliar', 'laku', 'hukum', 'amar', 'putus', 'majelis', 'hakim', 'meny']
# Memproses data ke-273:
# ['jual', 'gading', 'gajah', 'lazada', 'bukalapak', 'tokopedia', 'tuntut']
# Memproses data ke-274:
# ['jual', 'gading', 'gajah', 'lazada', 'bukalapak', 'tokopedia', 'tuntut']
# Memproses data ke-275:
# ['ditreskrimsus', 'polda', 'lampung', 'ekspos', 'jual', 'gading', 'gajah']
# Memproses data ke-276:
# ['colong', 'jual', 'gading', 'gajah', 'bukalapak', 'protes', 'petisi', 'online']
# Memproses data ke-277:
# ['jual', 'gading', 'gajah', 'rp', 'miliar', 'laku', 'hukum', 'amar', 'putus', 'majelis', 'hakim', 'meny']
# Memproses data ke-278:
# ['afgan', 'dengar', 'lagu', 'judul', 'sadis', 'isit', 'dipake', 'orang', 'orang', 'forum', 'jual', 'beli', 'kaskus', 'iklan', 'jual', 'motor', 'nego', 'no', 'afgan', 'nego', 'sadis']
# Memproses data ke-279:
# ['afgan', 'dengar', 'lagu', 'judul', 'sadis', 'isit', 'dipake', 'orang', 'orang', 'forum', 'jual', 'beli', 'kaskus', 'iklan', 'jual', 'motor', 'nego', 'no', 'afgan', 'nego', 'sadis']
# Memproses data ke-280:
# ['ihiirr', 'wts', 'cantik', 'beud', 'sapa', 'nama', 'jd', 'ken', 'kenal', 'wanitatahansumuk']
# Memproses data ke-281:
# ['wts', 'memek', 'memek', 'nd', 'kondisi', 'harga', 'rb', 'nego', 'tipis', 'ya', 'gan', 'minat', 'pm', 'ane', 'via']
# Memproses data ke-282:
# ['wts', 'ur', 'plan', 'so', 'i', 'nid', 'anoda', 'source', 'of', 'income']
# Memproses data ke-283:
# ['i', 'm', 'wif', 'u', 'on', 'dis', 'she', 'has', 'changed', 'handle', 'wice', 'todayrt', 'yo', 'wts', 'wiv', 'd', 'kuskus']
# Memproses data ke-284:
# ['facebook', 'pls', 'shift', 'with', 'your', 'fb', 'wts', 'wrong', 'with', 'david', 'luiz', 'keep', 'the', 'ball', 'on', 'd', 'ground', 'na']
# Memproses data ke-285:
# ['yo', 'wts', 'wiv', 'd', 'kuskus']
# Memproses data ke-286:
# ['jual', 'jual', 'baby', 'nappy', 'popok', 'bayi', 'cuci', 'ulang', 'insert', 'murah']
# Memproses data ke-287:
# ['jual', 'replika', 'casio', 'baby', 'g', 'murah', 'gan']
# Memproses data ke-288:
# ['minat', 'silah', 'cek', 'jual', 'baby', 'chair', 'nd', 'babydoes', 'kondisi']
# Memproses data ke-289:
# ['jual', 'unusual', 'lava', 'baby', 'roshan', 'dota', 'courier', 'semarang']
# Memproses data ke-290:
# ['jual', 'baby', 'fish', 'nila', 'keripik', 'er', 'mampir', 'yuk', 'd']
# Memproses data ke-291:
# ['jual', 'tokek', 'gr', 'jual', 'baby', 'otter', 'aneh', 'fjb', 'fauna', 'kaskus', 'ngakaks']
# Memproses data ke-292:
# ['jual', 'cepat', 'kamera', 'baby', 'holga', 'murah']
# Memproses data ke-293:
# ['jual', 'baby', 'box', 'pilih', 'baby', 'box', 'anak', 'klik']
# Memproses data ke-294:
# ['jual', 'kaos', 'kaskus', 'baby', 'boy', 'rp', 'rb', 'sms', 'grab', 'it', 'fast']
# Memproses data ke-295:
# ['jual', 'baby', 'batherbak', 'mandi', 'bayi', 'merk', 'summer', 'infant', 'ny']
# Memproses data ke-296:
# ['kaskus', 'jual', 'jersey', 'tuk', 'baby', 'asyiiiik', 'uy']
# Memproses data ke-297:
# ['jual', 'kemejamotogp', 'marquez', 'the', 'baby', 'alien', 'bahan', 'bagus', 'telp']
# Memproses data ke-298:
# ['baby', 'food', 'and', 'soups', 'info', 'jual', 'dekat']
# Memproses data ke-299:
# ['jual', 'ex', 'kadostuff', 'baby', 'baby', 'playmate', 'gendong', 'bayi', 'selimut', 'topi', 'dll']
# Memproses data ke-300:
# ['jumper', 'bayi', 'jumper', 'bola', 'jumper', 'bola', 'bayi', 'jumper', 'bola', 'baby', 'jual', 'jumper', 'bola', 'bayi', 'kaskus', 'jumper', 'bola', 'murah']
# Memproses data ke-301:
# ['jual', 'dunlop', 'cry', 'baby', 'for', 'bass', 'kaskus', 'harga', 'miring', 'tp', 'kondisi', 'nya', 'bimbang']
# Memproses data ke-302:
# ['buka', 'lapak', 'gan', 'jual', 'mazda', 'baby', 'boomers', 'th', 'kondisi', 'warna', 'ungu', 'terong', 'strip', 'putih', 'velk']
# Memproses data ke-303:
# ['infocekidot', 'kaskus', 'jual', 'kaos', 'pre', 'order', 'baby', 'ironman', 'and', 'captain', 'america', 'jeans', 'nudie', 'dll', 'jegging', 'zara', 'lt', 'detail']
# Memproses data ke-304:
# ['jual', 'baby', 'cube', 'murah', 'ya', 'tks']
# Memproses data ke-305:
# ['jual', 'baju', 'jaket', 'jumper', 'baby', 'anak', 'anak']
# Memproses data ke-306:
# ['gan', 'jual', 'sepatu', 'baby', 'pre', 'walker', 'mampir', 'gan', 'd']
# Memproses data ke-307:
# ['info', 'donk', 'kah', 'jual', 'baby', 'car', 'seat', 'semarang', 'tq']
# Memproses data ke-308:
# ['sippppp', 'tenang', 'ajahhhhh', 'pasang', 'iklan', 'jual', 'baby', 'ndut', 'kaskus']
# Memproses data ke-309:
# ['ryo', 'baby', 'shop', 'jual', 'lengkap', 'bayi', 'baju', 'celana', 'aksesoris', 'dll']
# Memproses data ke-310:
# ['yoi', 'ki', 'akhrnya', 'keupgrade', 'jg', 'tuh', 'my', 'baby', 'jual', 'agan', 'kaskus', 'd']
# Memproses data ke-311:
# ['jual', 'dress', 'baju', 'sepatu', 'baby', 'lucu', 'details', 'add', 'pin', 'a', 'c', 'fb', 'page', 'balqishop']
# Memproses data ke-312:
# ['lt', 'qimbee', 'baby', 'shop', 'jogja', 'jual', 'tutup', 'karet', 'botol', 'asi', 'murah', 'via']
# Memproses data ke-313:
# ['jual', 'baby', 'box', 'cahaya']
# Memproses data ke-314:
# ['jual', 'nd', 'stroller', 'baby', 'elle', 'lokasi', 'graha', 'raya', 'tipe', 'infinite', 'tosca', 'very', 'good', 'condition', 'k', 'nego', 'i', 'd', 'kaskus', 'nchuny', 'tq']
# Memproses data ke-315:
# ['jual', 'new', 'stuff', 'ex', 'kado', 'baby', 'new', 'born', 'baju', 'botol', 'tomtip', 'gendong', 'elegance', 'dll']
# Memproses data ke-316:
# ['ga', 'jual', 'kaos', 'gambar', 'baby', 'huey', 'yak', 'jual', 'hayoo', 'tarik']
# Memproses data ke-317:
# ['ngahahaha', 'liat', 'kaskus', 'nyari', 'anak', 'anjing', 'jual', 'baby', 'yorkshire', 'nama', 'pinokio', 'pepito', 'pepiko', 'von', 'agassi', 'ya', 'ampuuun', 'eppy']
# Memproses data ke-318:
# ['bro', 'gw', 'liat', 'kaskus', 'ad', 'jual', 'baby', 'monop', 'wageo', 'rb', 'murah', 'stok', 'cod', 'bandung', 'gw', 'rencana', 'narik']
# Memproses data ke-319:
# ['jual', 'cream', 'walet', 'acai', 'berry', 'anion', 'lotion', 'baby', 'pink', 'dha', 'ori', 'dll', 'pin', 'e', 'spesial', 'hrga']
# Memproses data ke-320:
# ['renti', 'liat', 'forum', 'jual', 'beli', 'baby', 'beli', 'baju', 'bayi', 'ntar', 'ga', 'kepake', 'huhuhu', 'padahal', 'bayi', 'cpt']
# Memproses data ke-321:
# ['sulit', 'cari', 'saranin', 'cari', 'kaskus', 'info', 'jual', 'topeng', 'baby', 'metal', 'ga', 'min']
# Memproses data ke-322:
# ['pls', 'pm', 'lengkap', 'baby', 'sale', 'jual', 'brg', 'babyshop', 'krn', 'gk', 'jual', 'lg']
# Memproses data ke-323:
# ['pin', 'f', 'd', 'jual', 'celana', 'chino', 'man', 'woman', 'sepatu', 'converse', 'grade', 'ori', 'jaket', 'jeans', 'cwo', 'cwe', 'baby', 'g', 'dll']
# Memproses data ke-324:
# ['coba', 'cri', 'twitter', 'fb', 'kaskus', 'jual', 'dvd', 'gtuan', 'klo', 'ktemu', 'blg', 'yaa', 'cha', 'ak', 'bli', 'dvd', 'hello', 'baby', 'itnw', 'konser', 'a']
# Memproses data ke-325:
# ['cari', 'kaskus', 'baby', 'org', 'jual', 'helm', 'doank', 'tp', 'hrus', 'cod', 'udh', 'tipu', 'smua', 'pke', 'kirim']
# Memproses data ke-326:
# ['jual', 'kaos', 'kaskus', 'baby', 'girl', 'rp', 'rb', 'sms', 'grab', 'it', 'fast']
# Memproses data ke-327:
# ['jual', 'replika', 'casio', 'baby', 'g', 'murah', 'gan']
# Memproses data ke-328:
# ['jual', 'distro', 'baby', 'jumper', 'baju', 'kodok', 'bola']
# Memproses data ke-329:
# ['jumper', 'bayi', 'jumper', 'bola', 'jumper', 'bola', 'bayi', 'jumper', 'bola', 'baby', 'jual', 'jumper', 'bola', 'bayi', 'kaskus', 'jumper', 'bola', 'murah']
# Memproses data ke-330:
# ['minat', 'silah', 'cek', 'jual', 'baby', 'chair', 'nd', 'babydoes', 'kondisi']
# Memproses data ke-331:
# ['jual', 'kemeja', 'motogp', 'marquez', 'the', 'baby', 'alien', 'bahan', 'bagus', 'sms']
# Memproses data ke-332:
# ['jual', 'jersey', 'grade', 'ori', 'jaket', 'tas', 'futsal', 'baby', 'jumper', 'cp', 'komp', 'pasar', 'segar', 'kbi', 'tki', 'ii']
# Memproses data ke-333:
# ['buka', 'kaskus', 'nama', 'raffi', 'shop', 'jual', 'kolam', 'renang', 'plastik', 'murah', 'riah', 'ama', 'baby', 'pool', 'knapa', 'lucu']
# Memproses data ke-334:
# ['maaf', 'promo', 'jual', 'baju', 'anak', 'online', 'follow', 'me', 'baby', 'shop', 'online']
# Memproses data ke-335:
# ['jual', 'baby', 'box']
# Memproses data ke-336:
# ['jual', 'legging', 'baby', 'cotton', 'rich']
# Memproses data ke-337:
# ['jual', 'music', 'baby', 'speaker']
# Memproses data ke-338:
# ['jual', 'tanktop', 'baby', 'milo', 'kaget']
# Memproses data ke-339:
# ['jual', 'cry', 'baby', 'bass', 'q']
# Memproses data ke-340:
# ['jual', 'gendong', 'baby', 'scots', 'slingrider', 'via']
# Memproses data ke-341:
# ['jual', 'great', 'lens', 'minolta', 'mm', 'f', 'baby', 'beercan']
# Memproses data ke-342:
# ['jual', 'pigeon', 'home', 'baby', 'food', 'maker']
# Memproses data ke-343:
# ['jual', 'sony', 'alpha', 'beercan', 'baby', 'beercan', 'fujinon', 'ebc', 'helios']
# Memproses data ke-344:
# ['set', 'baby', 'pink']
# Memproses data ke-345:
# ['someone', 'found', 'jual', 'topi', 'kupluk', 'anak', 'cute', 'bahan', 'rajut', 'from', 'google', 'co', 'id', 'with', 'keyword', 'topi', 'kupluk', 'baby', 'kaskus']
# Memproses data ke-346:
# ['jual', 'baby', 'shoes', 'converse', 'original', 'pediped', 'robeez']
# Memproses data ke-347:
# ['jual', 'boss', 'syb', 'boss', 'geb', 'boss', 'aw', 'big', 'muff', 'russian', 'cry', 'baby', 'bass', 'ibanez', 'sb']
# Memproses data ke-348:
# ['twin', 'tulipware', 'baby', 'stuffs', 'and', 'more', 'chat', 'me', 'for', 'further', 'information', 'forum', 'jual', 'beli', 'kaskus', 'link']
# Memproses data ke-349:
# ['jual', 'cepat', 'akun', 'hosting', 'hosgator', 'baby', 'plan', 'bonus', 'domain', 'blog', 'amazon', 'manual']
# Memproses data ke-350:
# ['jual', 'jual', 'vagina', 'senter', 'baby', 'pussy', 'manual', 'getar', 'electric', 'hub']
# Memproses data ke-351:
# ['capdase', 'polimor', 'iphone', 's', 'baby', 'soft', 'pink', 'sold', 'out', 'o', 'thanks', 'all']
# Memproses data ke-352:
# ['jual', 'fleshlight', 'masturbation', 'baby', 'pussy', 'vibration']
# Memproses data ke-353:
# ['jual', 'alat', 'bantu', 'pria', 'fleshlight', 'baby', 'pussy', 'pink', 'butt', 'pink', 'mouth']
# Memproses data ke-354:
# ['rental', 'baby', 'carrier', 'breastpump', 'pool', 'minggu', 'eaae']
# Memproses data ke-355:
# ['jual', 'jam', 'tangan', 'new', 'second', 'original', 'kw', 'supergrade', 'g', 'shock', 'baby', 'g', 'swatch', 'nixon', 'tag', 'heuer', 'dll', 'pin', 'fb', 'd']
# Memproses data ke-356:
# ['jual', 'crazy', 'sale', 'aneka', 'main', 'bayi']
# Memproses data ke-357:
# ['pitoong', 'jual', 'g', 'shock', 'mud', 'man', 'baby', 'g', 'sherina', 'murah', 'kaskus', 'sale', 'all', 'nego', 'kondisi', 'new', 'kw', 'supe', 'pitoong']
# Memproses data ke-358:
# ['jual', 'legging', 'baby', 'cotton', 'rich']
# Memproses data ke-359:
# ['jual', 'boss', 'syb', 'boss', 'geb', 'boss', 'aw', 'big', 'muff', 'russian', 'cry', 'baby', 'bass', 'dunlop', 'ibanez', 'sb']
# Memproses data ke-360:
# ['jual', 'seprei', 'anti', 'ompol']
# Memproses data ke-361:
# ['l', 'idr', 'l', 'baby', 'pink']
# Memproses data ke-362:
# ['jual', 'jual', 'baby', 'nappy', 'popok', 'bayi', 'cuci', 'ulang', 'insert', 'murah']
# Memproses data ke-363:
# ['jual', 'wet', 'bag', 'wetbag', 'tas', 'renang', 'baju', 'kotor', 'bayi']
# Memproses data ke-364:
# ['urgent', 'tau', 'jual', 'boneka', 'bayi', 'gundul']
# Memproses data ke-365:
# ['sulit', 'bayar', 'salin', 'jual', 'pasang', 'bayi', 'kembar']
# Memproses data ke-366:
# ['jual', 'iphone', 'gs', 'gb', 'black', 'mulus', 'kayak', 'pantat', 'bayi', 'murahhhhh']
# Memproses data ke-367:
# ['wa', 'jual', 'turban', 'bayi', 'kaskus']
# Memproses data ke-368:
# ['jual', 'beli', 'bayi', 'ala', 'china']
# Memproses data ke-369:
# ['jual', 'bando', 'bayi', 'import', 'dr', 'rb']
# Memproses data ke-370:
# ['edan', 'banget', 'nih', 'gan', 'jual', 'bayi', 'fjb', 'gue', 'ga', 'boong', 'hajarrrrrr']
# Memproses data ke-371:
# ['ready', 'stock', 'jual', 'tas', 'bayi', 'modis', 'praktis', 'muat', 'lengkap', 'bayi', 'tahan', 'air']
# Memproses data ke-372:
# ['jual', 'pakai', 'bayi']
# Memproses data ke-373:
# ['jual', 'popok', 'bayi', 'second', 'mending', 'kaskus', 'olx', 'ya']
# Memproses data ke-374:
# ['ready', 'stock', 'jual', 'selimut', 'bayi', 'design', 'unik', 'praktis']
# Memproses data ke-375:
# ['gila', 'bro', 'fjb', 'jual', 'bayi']
# Memproses data ke-376:
# ['jual', 'bayi', 'dokter', 'kandung', 'ancam', 'hukum', 'mati', 'update']
# Memproses data ke-377:
# ['sewa', 'jual', 'bayi']
# Memproses data ke-378:
# ['kaskus', 'gak', 'jual', 'bayi', 'singa', 'payah']
# Memproses data ke-379:
# ['pria', 'amerika', 'penjara', 'usaha', 'jual', 'bayi', 'harga', 'dolar', 'as']
# Memproses data ke-380:
# ['jual', 'babybag', 'tas', 'bayi', 'harga', 'rp']
# Memproses data ke-381:
# ['someone', 'found', 'jual', 'baju', 'renang', 'bayi', 'anak', 'anak', 'from', 'google', 'co', 'id', 'with', 'keyword', 'baju', 'renang', 'kaskus']
# Memproses data ke-382:
# ['ryo', 'baby', 'shop', 'jual', 'lengkap', 'bayi', 'baju', 'celana', 'aksesoris', 'dll']
# Memproses data ke-383:
# ['astaga', 'masjid', 'agung', 'tasik', 'jual', 'abis', 'jual', 'bayi', 'skrg', 'jual', 'masjid']
# Memproses data ke-384:
# ['jual', 'lengkap', 'anak', 'bayi', 'main', 'anak', 'kado', 'lengkap']
# Memproses data ke-385:
# ['jual', 'car', 'seat', 'bayi', 'murah', 'jakarta']
# Memproses data ke-386:
# ['new', 'post', 'jual', 'turban', 'bayi', 'kaskus', 'wa', 'has', 'been', 'published', 'on', 'rifara', 'hijab', 'anak']
# Memproses data ke-387:
# ['set', 'kaskus', 'jual', 'bayi', 'sarap', 'orang']
# Memproses data ke-388:
# ['jual', 'bayi', 'pasien', 'dokter', 'china', 'hukum', 'mati', 'update']
# Memproses data ke-389:
# ['kaskus', 'ga', 'forum', 'kaya', 'forum', 'belah', 'yah', 'jual', 'beli', 'bayi', 'xd']
# Memproses data ke-390:
# ['jual', 'beli', 'bayi', 'toko', 'bagus', 'colong', 'rame', 'kaskus']
# Memproses data ke-391:
# ['gawat', 'gan', 'miyabi', 'alih', 'profesi', 'jual', 'tas', 'gantung', 'bayi', 'no', 'hoax', 'cekidot', 'gan']
# Memproses data ke-392:
# ['berita', 'jual', 'beli', 'bayi', 'juta', 'tokobagus', 'kaskus', 'udah', 'ya']
# Memproses data ke-393:
# ['hot', 'news', 'astagfirullah', 'kakek', 'jual', 'bayi', 'putri', 'facebook']
# Memproses data ke-394:
# ['jual', 'baby', 'batherbak', 'mandi', 'bayi', 'merk', 'summer', 'infant', 'ny']
# Memproses data ke-395:
# ['jual', 'barang', 'hadiah', 'lengkap', 'bayi']
# Memproses data ke-396:
# ['jual', 'ps', 'mulus', 'kayak', 'pantat', 'bayi', 'tipu', 'rekber', 'img']
# Memproses data ke-397:
# ['jual', 'timbang', 'ukur', 'badan', 'bayi', 'anak', 'digital', 'laica']
# Memproses data ke-398:
# ['emang', 'kaskus', 'tuh', 'forum', 'jual', 'beli', 'canggih', 'stengah', 'jam', 'posting', 'jual', 'lengkap', 'bayi', 'udh', 'bbrp', 'email', 'nanya', 'hebat', 'euy']
# Memproses data ke-399:
# ['fjb', 'kaskus', 'jual', 'lengkap', 'bayi', 'banget', 'ya', 'mikirnya']
# Memproses data ke-400:
# ['jual', 'bayi', 'ham', 'bayi', 'macan', 'hahahha', 'iye', 'yog', 'aneh', 'tar', 'w', 'jual', 'bayi', 'beda', 'ham', 'ma', 'kaskus']
# Memproses data ke-401:
# ['jumper', 'bayi', 'jumper', 'bola', 'jumper', 'bola', 'bayi', 'jumper', 'bola', 'baby', 'jual', 'jumper', 'bola', 'bayi', 'kaskus', 'jumper', 'bola', 'murah']
# Memproses data ke-402:
# ['tokobagoes', 'jual', 'bayi', 'ane', 'jual', 'gmn', 'gan']
# Memproses data ke-403:
# ['buset', 'brohhh', 'jual', 'bayi', 'jual', 'nye', 'tokobagus', 'aje', 'kaskus', 'biar', 'dpt', 'cendol', 'otak', 'lau', 'jempol', 'kaki', 'brohhh']
# Memproses data ke-404:
# ['jual', 'botol', 'dot', 'bayi', 'merek', 'medela', 'kabarin', 'atw', 'twiett', 'quw']
# Memproses data ke-405:
# ['jual', 'jual', 'ipad', 'gb', 'g', 'black', 'mulus', 'kaya', 'pantat', 'bayi', 'bonus']
# Memproses data ke-406:
# ['jual', 'bayi', 'kaskus', 'ga', 'jeez', 'edan', 'kaya', 'barang', 'ajaa']
# Memproses data ke-407:
# ['pria', 'amerika', 'penjara', 'usaha', 'jual', 'bayi', 'harga', 'dolar', 'as']
# Memproses data ke-408:
# ['fjb', 'kaskus', 'jual', 'bayi', 'gila']
# Memproses data ke-409:
# ['jual', 'tas', 'bayi', 'modis', 'praktis', 'muat', 'lengkap', 'bayi', 'tahan', 'air']
# Memproses data ke-410:
# ['ready', 'stock', 'jual', 'selimut', 'bayi', 'design', 'unik', 'praktis']
# Memproses data ke-411:
# ['gila', 'bro', 'fjb', 'jual', 'bayi']
# Memproses data ke-412:
# ['jual', 'car', 'seat', 'bayi', 'murah', 'jakarta']
# Memproses data ke-413:
# ['pagi', 'baca', 'tl', 'byk', 'mbahas', 'anak', 'jual', 'ginjal', 'kaskus', 'jual', 'bayi', 'tokobagus']
# Memproses data ke-414:
# ['astagfirullah', 'kakek', 'jual', 'bayi', 'putri', 'facebook', 'img']
# Memproses data ke-415:
# ['jumper', 'bayi', 'jumper', 'bola', 'jumper', 'bola', 'bayi', 'jumper', 'bola', 'baby', 'jual', 'jumper', 'bola', 'bayi', 'kaskus', 'jumper', 'bola', 'murah']
# Memproses data ke-416:
# ['netizen', 'heboh', 'bayi', 'perempuan', 'jual', 'ebay']
# Memproses data ke-417:
# ['alhamdulilah', 'habis', 'threat', 'kaskus', 'jual', 'bayi', 'ken', 'bayi', 'mulus', 'lahir', 'jam', 'langsung', 'dapet', 'pertamax', 'gan', 'cendol', 'gan']
# Memproses data ke-418:
# ['wakil', 'rakyat', 'pake', 'internet', 'utk', 'nal', 'dgn', 'kihidupan', 'rakyat', 'miskin', 'wakil', 'rakyat', 'das', 'ga', 'tau', 'kaskus', 'jual', 'bayi']
# Memproses data ke-419:
# ['kemaren', 'jual', 'bayi', 'toko', 'bagus', 'jual', 'kuntilanak', 'kaskus', 'aya', 'wae']
# Memproses data ke-420:
# ...
# Memproses data ke-1541:
# ['bksda', 'aman', 'ajar', 'jual', 'kukang']
# Memproses data ke-1542:
# ['jual', 'landak', 'kukang', 'wa', 'siswa', 'majalengka', 'minum', 'badak', 'pakek', 'bakwan', 'bikin', 'wa', 'senang']
# Memproses data ke-1543:
# ['kukang', 'jual', 'ilegal', 'pelihara', 'bgt', 'jadi', 'kukang', 'hewan', 'pelihara', 'krn', 'fisik', 'cute', 'unyu']
# Memproses data ke-1544:
# ['pleasee', 'jual', 'kukkang', 'jgn', 'ccabut', 'gigi', 'kukang', 'ku', 'ajjah', 'alami', 'a', 'kasi', 'kukang', 'punah']
# Memproses data ke-1545:
# ['nggak', 'tiru', 'ya', 'sahabat', 'jual', 'kukang', 'via', 'facebook', 'ajar', 'bogor', 'tangkap']
# Memproses data ke-1546:
# ['profauna', 'jual', 'beli', 'kukang', 'alih', 'internet']
# Memproses data ke-1547:
# ['jual', 'pelihara', 'kukang', 'jakarta', 'greeners', 'pelihara', 'hewan', 'kukang', 'tangkap', 'o']
# Memproses data ke-1548:
# ['via', 'hewan', 'kukang', 'lampung', 'sasar', 'jual', 'pulau', 'jawa', 'untung', 'tangkap', 'jual']
# Memproses data ke-1549:
# ['sore', 'sore', 'abis', 'boci', 'kirim', 'mamaa', 'jenis', 'kukang', 'katanyaa', 'org', 'jual', 'bawa', 'kesana', 'kemari', 'mama', 'pic']
# Memproses data ke-1550:
# ['kepul', 'jual', 'satwa', 'lindung', 'jenis', 'kukang', 'facebook', 'polda', 'jabar', 'aman', 'ekor', 'kukang', 'h']
# Memproses data ke-1551:
# ['si', 'reporter', 'pura', 'jd', 'turis', 'mancanegara', 'nang', 'ktk', 'hewan', 'langka', 'spt', 'kukang', 'jual', 'bebas', 'ga', 'dpt', 'laku']
# Memproses data ke-1552:
# ['jual', 'ekor', 'kukang', 'anak', 'urus', 'hukum', 'via']
# Memproses data ke-1553:
# ['populasi', 'kukang', 'punah', 'hilang', 'habitat', 'buru', 'rajalela', 'jual', 'ancam', 'punah', 'kukang']
# Memproses data ke-1554:
# ['warga', 'diri', 'jual', 'kukang', 'burung', 'julang']
# Memproses data ke-1555:
# ['denger', 'jual', 'satwa', 'langka', 'gorila', 'muka', 'helm', 'kukang', 'naek', 'motor', 'diam', 'bpk', 'robby', 'gobel']
# Memproses data ke-1556:
# ['jual', 'kukang', 'ular', 'gogon', 'ringkus', 'polisi', 'kandang', 'disembunyiin', 'tau', 'lindung']
# Memproses data ke-1557:
# ['bantu', 'jual', 'hasil', 'panen', 'sembako', 'misi', 'replies', 'nakamura', 'ayum', 'kitsunebi', 'kit', 'matsudaira', 'gin', 'kuk', 'kuk', 'hoshizora', 'haruki', 'mizuchi', 'miz', 'fujiwara', 'akemi', 'mizuchi', 'miz']
# Memproses data ke-1558:
# ['jual', 'kukang', 'rp', 'juta', 'ayah', 'anak', 'tangkap', 'polhut', 'via']
# Memproses data ke-1559:
# ['jual', 'kukang', 'jawa', 'via', 'facebook', 'orang', 'bekuk', 'polisi', 'okezone']
# Memproses data ke-1560:
# ['jual', 'kukang', 'jawa', 'via', 'facebook', 'mahasiswa', 'tahan', 'polisi', 'tangkap']
# Memproses data ke-1561:
# ['jual', 'kukang', 'rp', 'juta', 'ayah', 'anak', 'tangkap', 'polhut']
# Memproses data ke-1562:
# ['jual', 'ekor', 'kukang', 'anak', 'urus', 'hukum']
# Memproses data ke-1563:
# ['kepul', 'jual', 'satwa', 'lindung', 'jenis', 'kukang', 'facebook', 'polda', 'jabar', 'aman', 'ekor', 'kukang', 'h']
# Memproses data ke-1564:
# ['hewan', 'kukang', 'lampung', 'sasar', 'jual', 'pulau', 'jawa', 'untung', 'tangkap', 'jual']
# Memproses data ke-1565:
# ['jual', 'kukang', 'burung', 'julang', 'emas', 'dagang', 'hewan', 'diri', 'aman', 'tugas', 'balai', 'gakkum', 'klhk']
# Memproses data ke-1566:
# ['profauna', 'jual', 'beli', 'kukang', 'alih', 'internet']
# Memproses data ke-1567:
# ['bongkar', 'dagang', 'kukang', 'via', 'internet', 'praktik', 'jual', 'beli', 'hewan', 'langka', 'lindung', 'negara', 'bongkar', 'apar']
# Memproses data ke-1568:
# ['jual', 'elang', 'jawa', 'kukang', 'langka', 'oknum', 'aparat', 'dki', 'tangkap', 'polisi', 'aparat', 'bksda', 'dki', 'jakarta', 'mel']
# Memproses data ke-1569:
# ['jual', 'kukang', 'penjara', 'yah', 'kukang', 'loh', 'lucu', 'duiit']
# Memproses data ke-1570:
# ['duh', 'kukang', 'diperjualbelikan', 'dunia', 'maya', 'primata', 'primadona', 'jual', 'beli', 'satwa', 'langka']
# Memproses data ke-1571:
# ['jual', 'kukang', 'lutung', 'facebook', 'tani', 'masuk', 'bui', 'via']
# Memproses data ke-1572:
# ['pdhl', 'ya', 'pasar', 'curug', 'jg', 'bgt', 'jual', 'kucing', 'hutan', 'ngejual', 'kukang', 'jalak', 'bal', 'jg', 'gatau', 'skrg', 'mas', 'jual', 'engga', 'jg', 'gatau', 'legal', 'ilegal', 'bapak', 'perna', 'tawarin', 'temennya', 'kucing', 'hutan', 'hasil', 'buru']
# Memproses data ke-1573:
# ['coba', 'coba', 'iseng', 'jual', 'kukang', 'ingat']
# Memproses data ke-1574:
# ['nang', 'mecut', 'bena', 'cod', 'ritok', 'jam', 'tok', 'dah', 'nal', 'settle', 'dah', 'cod', 'kuk']
# Memproses data ke-1575:
# ['apa', 'kuk', 'slalu', 'untuk']
# Memproses data ke-1576:
# ['derita', 'hewan', 'buru', 'gara', 'gara', 'wajah', 'imut', 'kukang', 'serah', 'w']
# Memproses data ke-1577:
# ['potret', 'tembus', 'batas', 'kekang', 'kukang', 'kukang', 'tangkap', 'alam', 'alami', 'siksa']
# Memproses data ke-1578:
# ['kukang', 'bangun', 'kukang', 'beda', 'lg', 'imamberlian', 'lucu', 'hewan', 'kayak', 'pinguin', 'madagaskar']
# Memproses data ke-1579:
# ['wehhhhh', 'denger', 'a', 'besok', 'gw', 'berubahh', 'jd', 'kukang', 'jual', 'anak', 'orang', 'wkwkwkkkwkkwkrt', 'iye', 'autis', 'tukang']
# Memproses data ke-1580:
# ['ayah', 'anak', 'jual', 'ekor', 'kukang', 'tangkap']
# Memproses data ke-1581:
# ['omg', 'jual', 'anak', 'kukang', 'lampu', 'merah', 'bunderan', 'sudirman', 'polisi', 'diam']
# Memproses data ke-1582:
# ['ayah', 'anak', 'aman', 'jual', 'kukang', 'sumatera', 'ayah', 'anak', 'inisial', 'p', 'bh']
# Memproses data ke-1583:
# ['jual', 'lu', 'mending', 'gimana', 'saik', 'dah', 'foto', 'ber', 'rama', 'bisnis', 'si', 'rey', 'jual', 'anak', 'kukang']
# Memproses data ke-1584:
# ['jual', 'ekor', 'kukang', 'anak', 'urus', 'hukum', 'via']
# Memproses data ke-1585:
# ['nyentel', 'larat', 'anak', 'kukang', 'with', 'caca', 'at', 'mama', 'jual', 'pulsa', 'pic']
# Memproses data ke-1586:
# ['jual', 'kukang', 'anak', 'tangkap']
# Memproses data ke-1587:
# ['jual', 'kukang', 'ayah', 'anak', 'tangkap', 'tugas', 'nyamar']
# Memproses data ke-1588:
# ['tolong', 'ngelegalin', 'dagang', 'kukang', 'otak', 'dibenerin', 'posisi', 'ntar', 'anak', 'lu', 'gue', 'jual', 'sirkus', 'lumba', 'lumba', 'nih']
# Memproses data ke-1589:
# ['jual', 'kukang', 'rp', 'juta', 'ayah', 'anak', 'tangkap', 'polhut', 'via']
# Memproses data ke-1590:
# ['mongabayid', 'jual', 'kukang', 'ayah', 'anak', 'tangkap', 'tugas', 'nyamar', 'balai', 'aman', 'tega', 'hukum', 'li']
# Memproses data ke-1591:
# ['bip', 'jual', 'dirusuhin', 'anak', 'sd', 'kukang', 'jual', 'lepas', 'skrg', 'gentry', 'jual', 'umang', 'luk', 'gbr', 'naruto']
# Memproses data ke-1592:
# ['jual', 'ekor', 'kukang', 'anak', 'urus', 'hukum']
# Memproses data ke-1593:
# ['ayah', 'anak', 'aman', 'jual', 'kukang', 'sumatera', 'ayah', 'anak', 'inisial', 'p', 'bh']
# Memproses data ke-1594:
# ['jual', 'kukang', 'anak', 'tangkap', 'via']
# Memproses data ke-1595:
# ['jual', 'kukang', 'ayah', 'anak', 'tangkap', 'tugas', 'nyamar', 'balai', 'aman', 'tega', 'hukum', 'lingkung', 'hid']
# Memproses data ke-1596:
# ['jual', 'kukang', 'ayah', 'anak', 'tangkap', 'tugas', 'nyamar', 'via']
# Memproses data ke-1597:
# ['jual', 'kukang', 'rp', 'juta', 'ayah', 'anak', 'tangkap', 'polhut', 'via']
# Memproses data ke-1598:
# ['jual', 'kukang', 'ayah', 'anak', 'tangkap', 'tugas', 'nyamar']
# Memproses data ke-1599:
# ['jual', 'ekor', 'kukang', 'anak', 'urus', 'hukum']
# Memproses data ke-1600:
# ['ayah', 'anak', 'aman', 'jual', 'kukang', 'sumatera']
# Memproses data ke-1601:
# ['jual', 'kukang', 'rp', 'juta', 'ayah', 'anak', 'tangkap', 'polhut']
# Memproses data ke-1602:
# ['jual', 'ekor', 'kukang', 'anak', 'urus', 'hukum']
# Memproses data ke-1603:
# ['jual', 'kukang', 'ayah', 'anak', 'tangkap', 'tugas', 'nyamar']
# Memproses data ke-1604:
# ['jual', 'kukang', 'rp', 'juta', 'ayah', 'anak', 'tangkap', 'polhut']
# Memproses data ke-1605:
# ['jual', 'kukang', 'ayah', 'anak', 'tangkap', 'tugas', 'nyamar', 'via']
# Memproses data ke-1606:
# ['jual', 'kukang', 'ayah', 'anak', 'tangkap', 'tugas', 'nyamar', 'balai', 'aman', 'p', 'via']
# Memproses data ke-1607:
# ['jual', 'kukang', 'ayah', 'anak', 'tangkap', 'tugas', 'nyamar']
# Memproses data ke-1608:
# ['utk', 'kesan', 'kukang', 'satwa', 'jinak', 'lucu', 'gigina', 'cabut', 'dgn', 'tang', 'dagang']
# Memproses data ke-1609:
# ['temu', 'kukang', 'harap', 'hubung', 'milik', 'dah', 'udah', 'jinak', 'makasih']
# Memproses data ke-1610:
# ['tampil', 'kesan', 'kukang', 'satwa', 'jinak', 'lucu', 'gigit']
# Memproses data ke-1611:
# ['la', 'kukang', 'sayang', 'sy', 'dh', 'jinak']
# Memproses data ke-1612:
# ['ayuha', 'mang', 'ae', 'kukang', 'ganas', 'kytu', 'sambat', 'jinak', 'haha', 'ngelupis', 'duluuu']
# Memproses data ke-1613:
# ['gak', 'jinak', 'jinak', 'kukang']
# Memproses data ke-1614:
# ['alas', 'gigi', 'kukang', 'cabut', 'dagang', 'kukang', 'jinak', 'peduli', 'kondisi', 'kukang', 'tsb']
# Memproses data ke-1615:
# ['kukang', 'pajang', 'poto', 'dah', 'nda', 'gigi', 'kukang', 'cabut', 'paksa', 'gigi', 'biar', 'liat', 'jinak']
# Memproses data ke-1616:
# ['kukang', 'taring', 'kes', 'lucu', 'jinak', 'spjng', 'profauna', 'catat', 'dagang', 'kukang', 'online']
# Memproses data ke-1617:
# ['kjhtn', 'thdp', 'satwa', 'liar', 'gigi', 'kukang', 'pelihara', 'cabut', 'kukang', 'putar', 'putar', 'jinak']
# Memproses data ke-1618:
# ['kukang', 'jinak', 'sayang']
# Memproses data ke-1619:
# ['tuh', 'kukang', 'tawarin', 'keren', 'taring', 'murah', 'minus', 'ga', 'jinak']
# Memproses data ke-1620:
# ['liat', 'video', 'kukang', 'gigi', 'potong', 'biar', 'liat', 'jinak', 'tindak', 'biadab', 'bgt']
# Memproses data ke-1621:
# ['kukang', 'tpi', 'jinak', 'ciko', 'pengenbangetpeliharabinatang']
# Memproses data ke-1622:
# ['tangan', 'dagang', 'gigi', 'kukang', 'cabut', 'jinak', 'gigit', 'pelihara']
# Memproses data ke-1623:
# ['ak', 'mimpi', 'keluarga', 'melihara', 'singa', 'harimau', 'macan', 'koala', 'kukang', 'singa', 'jinak', 'tp', 'deket', 'deket', 'dalem', 'rumah', 'khawatir', 'nerkam', 'suddenly', 'ya', 'yaudah', 'ak', 'mlindungi', 'masuk', 'kamar']
# Memproses data ke-1624:
# ['jual', 'gigi', 'kukang', 'potong', 'kukang', 'putar', 'putar', 'lemas', 'jinak']
# Memproses data ke-1625:
# ['cabut', 'gigi', 'buru', 'jual', 'jinak', 'bahaya', 'kukang']
# Memproses data ke-1626:
# ['gigi', 'kukang', 'cabut', 'dagang', 'jinak', 'salah', 'karna', 'siksa', 'hewan', 'sebab', 'mati', 'kukang']
# Memproses data ke-1627:
# ['tolong', 'tindak', 'hewn', 'langka', 'jaga', 'populasi', 'trima', 'ksh', 'beby', 'kukang', 'jinak', 'minat', 'pin', 'e']
# Memproses data ke-1628:
# ['pelihara', 'kukang', 'sugar', 'glider', 'jinak', 'lucu', 'd', 'p']
# Memproses data ke-1629:
# ['blum', 'boy', 'pernah', 'kukang', 'kuskus', 'jinak', 'boy', 'pegang', 'trus', 'tp', 'mw', 'beli', 'udah', 'jinak', 'jg', 'ko']
# Memproses data ke-1630:
# ['anjerr', 'gua', 'baca', 'wikipedia', 'dagang', 'kukang', 'sengaja', 'cabut', 'gigi', 'kukang', 'biar', 'kesan', 'hewan', 'jinak', 'astagaa']
# Memproses data ke-1631:
# ['senjata', 'andal', 'mnjadi', 'daya', 'jinak', 'manja', 'calon', 'beli']
# Memproses data ke-1632:
# ['buka', 'facebook', 'jualinm', 'kukang', 'bangga', 'nulisin', 'jinak', 'gigi']
# Memproses data ke-1633:
# ['kukang', 'potong', 'gigi', 'jinak', 'taring', 'racun', 'cacing', 'zoonosis', 'nocturnal', 'kukang', 'bkn', 'pet']
# Memproses data ke-1634:
# ['keji', 'kukang', 'potong', 'gigi', 'jinak']
# Memproses data ke-1635:
# ['waah', 'maling', 'ya', 'kukang', 'lu', 'enak', 'kali', 'gigit', 'kukang', 'enggak', 'jinak', 'rawat', 'dri', 'lahir']
# Memproses data ke-1636:
# ['kukang', 'satwa', 'nampak', 'lucu', 'gemesin', 'kukang', 'gera', 'lambat', 'kerap', 'tafsir', 'jinak']
# Memproses data ke-1637:
# ['jenis', 'kukang', 'jenis', 'untung', 'komodo', 'kadal', 'liar', 'kadal', 'jinak']
# Memproses data ke-1638:
# ['kukang', 'tra', 'jinak']
# Memproses data ke-1639:
# ['iyoh', 'maknya', 'wanirt', 'kukang', 'mu', 'jinak', 'kah']
# Memproses data ke-1640:
# ['smangat', 'kak', 'kukang', 'liar', 'jd', 'jinak', 'ama', 'kakak', 'volunteer', 'yayasan', 'international', 'animal', 'rescue', 'indonesia']
# Memproses data ke-1641:
# ['bahahah', 'kukang', 'ani', 'jinak', 'buka', 'liar', 'anu', 'kukang', 'liar', 'kesana', 'kemari', 'tu', 'si', 'nar', 'tu', 'eh', 'hahah']
# Memproses data ke-1642:
# ['gigi', 'patah', 'kikir', 'biar', 'kes', 'jinak', 'bayang', 'stop', 'pelihara', 'kukang']
# Memproses data ke-1643:
# ['kukang', 'si', 'binatang', 'jinak', 'ancam', 'punah', 'akibat', 'dagang', 'liar', 'cc']
# Memproses data ke-1644:
# ['kukang', 'klo', 'mw', 'dplihara', 'emang', 'dptong', 'giginy', 'biar', 'jinak', 'n', 'trnyta', 'ni', 'kukang', 'udh', 'brsmayam', 'd', 'sktar', 'kosan']
# Memproses data ke-1645:
# ['oh', 'kukang', 'mah', 'jinak', 'rb', 'baby', 'rb', 'jinak', 'jinak']
# Memproses data ke-1646:
# ['mb', 'umur', 'udh', 'jinak', 'makan', 'pisang', 'musangg', 'tpi', 'kukang', 'wekeke']
# Memproses data ke-1647:
# ['gak', 'tau', 'beline', 'mana', 'udah', 'jinak', 'loh', 'maurt', 'ken', 'beli', 'kukang', 'harga']
# Memproses data ke-1648:
# ['kukang', 'jg', 'cabut', 'taring', 'kes', 'jinak', 'tdk', 'gigit', 'racun', 'siku', 'bahaya']
# Memproses data ke-1649:
# ['did', 'u', 'know', 'klo', 'kukang', 'cabut', 'dl', 'gigi', 'puter', 'dg', 'posisi', 'kepala', 'd', 'bwh', 'sblm', 'jual', 'spy', 'liat', 'jinak']
# Memproses data ke-1650:
# ['de', 'su', 'sombong', 'tra', 'bikin', 'jinak', 'haha', 'peace', 'kukang']
# Memproses data ke-1651:
# ['tau', 'mati', 'kukang', 'gigi', 'cabut', 'kesan', 'kukang', 'hewan', 'jinak', 'lucu']
# Memproses data ke-1652:
# ['beneran', 'jd', 'piara', 'jinak', 'ya', 'tau', 'kukang', 'betina', 'temen', 'biar', 'ga', 'mati', 'gaya', 'sotoy', 'si', 'kukang']
# Memproses data ke-1653:
# ['atuh', 'kukang', 'ak', 'nti', 'jinak', 'koq', 'hahart', 'ga', 'kukang', 'km', 'galak', 'nya', 'cont']
# Memproses data ke-1654:
# ['kukang', 'kes', 'jinak', 'gigi', 'dipatahin', 'kikir', 'jd', 'ga', 'bs', 'makan', 'makan', 'jd', 'makan', 'pisang']
# Memproses data ke-1655:
# ['kukangjinak']
# Memproses data ke-1656:
# ['jual', 'ges', 'landak', 'ngerepoti']
# Memproses data ke-1657:
# ['cadang', 'nak', 'start', 'jual', 'tart', 'nenas', 'landak', 'ni', 'event', 'alhamdulillah', 'dah', 'customer', 'order', 'online', 'hihi']
# Memproses data ke-1658:
# ['jual', 'smart', 'detox', 'langsing', 'landak']
# Memproses data ke-1659:
# ['tau', 'ad', 'restoran', 'jual', 'landak', 'masak', 'lemak', 'omg']
# Memproses data ke-1660:
# ['jual', 'es', 'camelo', 'landak', 'kalbar', 'hub']
# Memproses data ke-1661:
# ['salfok', 'landak', 'mini', 'wkwk', 'mentang', 'gw', 'pasang', 'iklan', 'fb', 'jual', 'landak', 'mini', 'haha']
# Memproses data ke-1662:
# ['jual', 'trulum', 'skincare', 'landak', 'kalimantan', 'barat', 'wa']
# Memproses data ke-1663:
# ['gue', 'jual', 'kandang', 'landak', 'cek', 'harga', 'carousel', 'muncul', 'rumah', 'inimah', 'kandang', 'uwong']
# Memproses data ke-1664:
# ['jual', 'ayam', 'bangkok', 'landak']
# Memproses data ke-1665:
# ['punten', 'tau', 'jual', 'topi', 'utk', 'landak', 'mini', 'spt', 'mana', 'makasih']
# Memproses data ke-1666:
# ['jual', 'masker', 'muka', 'spirulina', 'tiens', 'landak', 'kalimantan', 'barat']
# Memproses data ke-1667:
# ['sape', 'jual', 'landak', 'salai', 'masak', 'lemak', 'cili', 'api']
# Memproses data ke-1668:
# ['jual', 'kostum', 'landak']
# Memproses data ke-1669:
# ['batu', 'perut', 'landak', 'jual', 'minat']
# Memproses data ke-1670:
# ['pria', 'aman', 'jual', 'kukang', 'landak', 'elang', 'diri']
# Memproses data ke-1671:
# ['jual', 'susu', 'provit', 'landak', 'lengkap', 'klik']
# Memproses data ke-1672:
# ['sembari', 'mules', 'mikirin', 'kambek', 'jnyeok', 'sembari', 'jual', 'gantung', 'akrilik', 'landak']
# Memproses data ke-1673:
# ['nama', 'restoren', 'kat', 'kuala', 'selangor', 'tu', 'jual', 'daging', 'landak', 'daging', 'rusa', 'someone', 'took', 'me', 'there', 'once', 'guess', 'in']
# Memproses data ke-1674:
# ['anyone', 'jual', 'daging', 'landak', 'i', 'mengidammmmmm', 'terukkk', 'niiii']
# Memproses data ke-1675:
# ['gak', 'jual', 'boneka', 'landak', 'lucu']
# Memproses data ke-1676:
# ['i', 'just', 'published', 'jual', 'obat', 'bius', 'landak', 'obat', 'tidur', 'lido', 'x', 'cair', 'ngabang']
# Memproses data ke-1677:
# ['usaha', 'jual', 'beli', 'ternak', 'landak', 'konsultasi', 'agama', 'didik', 'islam']
# Memproses data ke-1678:
# ['jual', 'landak', 'lindung', 'tani', 'tangkap']
# Memproses data ke-1679:
# ['sek', 'jual', 'rica', 'landak', 'sahurr']
# Memproses data ke-1680:
# ['jual', 'boneka', 'landak', 'mana', 'si']
# Sebanyak 1680 tweet telah diproses

# %%
#Memasukkan data hasil preprocessing ke dalam database
import mysql.connector

row=0
conn = mysql.connector.connect(host='localhost',user='root',password='',database='nlp2')
cursor = conn.cursor()
for i in listtoken:
    for j in i:
        query = ("INSERT INTO token_misc (token) values (%s)")
        #query = ("INSERT INTO token_wildlife_trade (token) values (%s)")
        value = (j,)
        try:
            cursor.execute(query,value)
            row+=1    
        except:
            print("error")
conn.commit()
conn.close()
print(row,"baris berhasil disimpan")
# Out:
# 20046 baris berhasil disimpan
